# %%
import pandas as pd

# %%
df = pd.read_csv('https://raw.githubusercontent.com/PCOS-Survey/PCOSData/master/PCOS-Data.csv')

# %%
df.head()
# Out:
#   patient Do You get menstural periods at regular intervals? (YES/NO)  \
# 0      p1                                                 hb
# 1      p2                                                 im
# 2      p3                                                 hb
# 3      p4                                                 ib
# 4      p5                                                 im
#
#   Are you gaining weight Rapidly? (YES/NO)  \
# 0                                        y
# 1                                        y
# 2                                        y
# 3                                        n
# 4                                        y
#
#   Do You have Excess of facial  or Body Hair ? (YES/NO)  \
# 0                                                  y
# 1                                                  y
# 2                                                  y
# 3                                                  y
# ...

# %%
df = df.drop('patient',axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 125 entries, 0 to 124
# Data columns (total 20 columns):
#  #   Column                                                                                     Non-Null Count  Dtype
# ---  ------                                                                                     --------------  -----
#  0   Do You get menstural periods at regular intervals? (YES/NO)                                119 non-null    object
#  1   Are you gaining weight Rapidly? (YES/NO)                                                   119 non-null    object
#  2   Do You have Excess of facial  or Body Hair ? (YES/NO)                                      117 non-null    object
#  3   Do you Have patches of dark areas on your skin?(Yes/No)                                    119 non-null    object
#  4   Do You suffer from pimples? (YES/NO)                                                       119 non-null    object
# ...

# %%
df.rename(columns={"Do You get menstural periods at regular intervals? (YES/NO)": "regular_periods"})
# Out:
#     regular_periods Are you gaining weight Rapidly? (YES/NO)  \
# 0                hb                                        y
# 1                im                                        y
# 2                hb                                        y
# 3                ib                                        n
# 4                im                                        y
# ..              ...                                      ...
# 120             NaN                                      NaN
# 121             NaN                                      NaN
# 122             NaN                                      NaN
# 123             NaN                                      NaN
# 124             NaN                                      NaN
#
#     Do You have Excess of facial  or Body Hair ? (YES/NO)  \
# 0                                                    y
# 1                                                    y
# 2                                                    y
# ...

# %%
df = df.rename(columns=
          {"Do You get menstural periods at regular intervals? (YES/NO)": "regular_periods",
          "Are you gaining weight Rapidly? (YES/NO)":"rapid_weight_gain",
           'Do You have Excess of facial  or Body Hair ? (YES/NO)':"excess_hair",
          "Do you Have patches of dark areas on your skin?(Yes/No)":"dark_patches",
          "Do You suffer from pimples? (YES/NO)":"pimples",
          "Do you face deppression and anxietyt? (YES/NO)":"depression_and_anxiety",
          "Do you any family history of Diabetics and Hyper Tension? (YES/NO)":"diabetic_hypertension_family_history",
          "Are you finding any difficulty in maintaining your body weight? (YES/NO)":"body_weight_maintain_difficulty",
           "Do you have na oily skin? (YES/NO)":"oily_skin",
          "Are you lossing lot of hair or has it became thinner in its strength? (YES/NO)":"hair_strength_loss",
          "Where do you Frequently eat?":"eat_frequency",
          "Do you exercise reguarly?":"regular_excercise",
          "I sleep after?":"sleep_time",
          "I wake up at?":"wake_time",
          "Are you mentally stressed due to following exercise? (Are you newly admitted to hostel ?)":"hostel_stress",
          "Are you mentally stressed due to following exercise? (Do you have personal problems?)":"personal_stress",
          "Are you mentally stressed due to following exercise?(peer presure?)": "peer_pressure",
          "Are you mentally stressed due to following exercise?(Change in dietry habits ?)":"dietary_stress",
          "How often do you eat fast foods?":"fast_food_frequency",
          "Class label":"PCOS"}
         )

# %%
df.head()
# Out:
#   regular_periods rapid_weight_gain excess_hair dark_patches pimples  \
# 0              hb                 y           y            n       y
# 1              im                 y           y            n       n
# 2              hb                 y           y            n       n
# 3              ib                 n           y            n       n
# 4              im                 y           y            n       n
#
#   depression_and_anxiety diabetic_hypertension_family_history  \
# 0                      y                                    n
# 1                      y                                    n
# 2                      y                                    n
# 3                      y                                    y
# 4                      y                                    y
#
#   body_weight_maintain_difficulty oily_skin hair_strength_loss eat_frequency  \
# 0                               y         y                  y            hm
# ...

# %%
df.columns
# Out:
# Index(['regular_periods', 'rapid_weight_gain', 'excess_hair', 'dark_patches',
#        'pimples', 'depression_and_anxiety',
#        'diabetic_hypertension_family_history',
#        'body_weight_maintain_difficulty', 'oily_skin', 'hair_strength_loss',
#        'eat_frequency', 'regular_excercise', 'sleep_time', 'wake_time',
#        'hostel_stress', 'personal_stress', 'peer_pressure', 'dietary_stress',
#        'fast_food_frequency', 'PCOS'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# regular_periods                         6
# rapid_weight_gain                       6
# excess_hair                             8
# dark_patches                            6
# pimples                                 6
# depression_and_anxiety                  7
# diabetic_hypertension_family_history    6
# body_weight_maintain_difficulty         6
# oily_skin                               6
# hair_strength_loss                      6
# eat_frequency                           6
# regular_excercise                       6
# sleep_time                              6
# wake_time                               6
# hostel_stress                           6
# personal_stress                         6
# peer_pressure                           6
# dietary_stress                          6
# fast_food_frequency                     6
# PCOS                                    6
# dtype: int64

# %%
df[df['regular_periods'].isna()]
# Out:
#     regular_periods rapid_weight_gain excess_hair dark_patches pimples  \
# 119             NaN               NaN         NaN          NaN     NaN
# 120             NaN               NaN         NaN          NaN     NaN
# 121             NaN               NaN         NaN          NaN     NaN
# 122             NaN               NaN         NaN          NaN     NaN
# 123             NaN               NaN         NaN          NaN     NaN
# 124             NaN               NaN         NaN          NaN     NaN
#
#     depression_and_anxiety diabetic_hypertension_family_history  \
# 119                    NaN                                  NaN
# 120                    NaN                                  NaN
# 121                    NaN                                  NaN
# 122                    NaN                                  NaN
# 123                    NaN                                  NaN
# 124                    NaN                                  NaN
#
# ...

# %%
df[df['depression_and_anxiety'].isna()]
# Out:
#     regular_periods rapid_weight_gain excess_hair dark_patches pimples  \
# 27              yes                 n           n            n       n
# 119             NaN               NaN         NaN          NaN     NaN
# 120             NaN               NaN         NaN          NaN     NaN
# 121             NaN               NaN         NaN          NaN     NaN
# 122             NaN               NaN         NaN          NaN     NaN
# 123             NaN               NaN         NaN          NaN     NaN
# 124             NaN               NaN         NaN          NaN     NaN
#
#     depression_and_anxiety diabetic_hypertension_family_history  \
# 27                     NaN                                    n
# 119                    NaN                                  NaN
# 120                    NaN                                  NaN
# 121                    NaN                                  NaN
# 122                    NaN                                  NaN
# ...

# %%
df.loc[[27]]
# Out:
#    regular_periods rapid_weight_gain excess_hair dark_patches pimples  \
# 27             yes                 n           n            n       n
#
#    depression_and_anxiety diabetic_hypertension_family_history  \
# 27                    NaN                                    n
#
#    body_weight_maintain_difficulty oily_skin hair_strength_loss eat_frequency  \
# 27                               n         n                  y            hm
#
#    regular_excercise sleep_time wake_time hostel_stress personal_stress  \
# 27                 n    11.00pm    7.00am             n               n
#
#    peer_pressure dietary_stress fast_food_frequency  PCOS
# 27             n              n                   w  mb n

# %%
df['depression_and_anxiety'][27] = 'n'

# %%
df.loc[[27]]
# Out:
#    regular_periods rapid_weight_gain excess_hair dark_patches pimples  \
# 27             yes                 n           n            n       n
#
#    depression_and_anxiety diabetic_hypertension_family_history  \
# 27                      n                                    n
#
#    body_weight_maintain_difficulty oily_skin hair_strength_loss eat_frequency  \
# 27                               n         n                  y            hm
#
#    regular_excercise sleep_time wake_time hostel_stress personal_stress  \
# 27                 n    11.00pm    7.00am             n               n
#
#    peer_pressure dietary_stress fast_food_frequency  PCOS
# 27             n              n                   w  mb n

# %%
df.isnull().sum()
# Out:
# regular_periods                         6
# rapid_weight_gain                       6
# excess_hair                             8
# dark_patches                            6
# pimples                                 6
# depression_and_anxiety                  6
# diabetic_hypertension_family_history    6
# body_weight_maintain_difficulty         6
# oily_skin                               6
# hair_strength_loss                      6
# eat_frequency                           6
# regular_excercise                       6
# sleep_time                              6
# wake_time                               6
# hostel_stress                           6
# personal_stress                         6
# peer_pressure                           6
# dietary_stress                          6
# fast_food_frequency                     6
# PCOS                                    6
# dtype: int64

# %%
df[df['excess_hair'].isna()]
# Out:
#     regular_periods rapid_weight_gain excess_hair dark_patches pimples  \
# 20               ib                 n         NaN            n       n
# 91               hb                 n         NaN            n       y
# 119             NaN               NaN         NaN          NaN     NaN
# 120             NaN               NaN         NaN          NaN     NaN
# 121             NaN               NaN         NaN          NaN     NaN
# 122             NaN               NaN         NaN          NaN     NaN
# 123             NaN               NaN         NaN          NaN     NaN
# 124             NaN               NaN         NaN          NaN     NaN
#
#     depression_and_anxiety diabetic_hypertension_family_history  \
# 20                       n                                    n
# 91                       y                                    n
# 119                    NaN                                  NaN
# 120                    NaN                                  NaN
# ...

# %%
df['excess_hair'][20] = 'n'
df['excess_hair'][91] = 'n'

# %%
df.isnull().sum()
# Out:
# regular_periods                         6
# rapid_weight_gain                       6
# excess_hair                             6
# dark_patches                            6
# pimples                                 6
# depression_and_anxiety                  6
# diabetic_hypertension_family_history    6
# body_weight_maintain_difficulty         6
# oily_skin                               6
# hair_strength_loss                      6
# eat_frequency                           6
# regular_excercise                       6
# sleep_time                              6
# wake_time                               6
# hostel_stress                           6
# personal_stress                         6
# peer_pressure                           6
# dietary_stress                          6
# fast_food_frequency                     6
# PCOS                                    6
# dtype: int64

# %%
df[df['depression_and_anxiety'].isna()]
# Out:
#     regular_periods rapid_weight_gain excess_hair dark_patches pimples  \
# 119             NaN               NaN         NaN          NaN     NaN
# 120             NaN               NaN         NaN          NaN     NaN
# 121             NaN               NaN         NaN          NaN     NaN
# 122             NaN               NaN         NaN          NaN     NaN
# 123             NaN               NaN         NaN          NaN     NaN
# 124             NaN               NaN         NaN          NaN     NaN
#
#     depression_and_anxiety diabetic_hypertension_family_history  \
# 119                    NaN                                  NaN
# 120                    NaN                                  NaN
# 121                    NaN                                  NaN
# 122                    NaN                                  NaN
# 123                    NaN                                  NaN
# 124                    NaN                                  NaN
#
# ...

# %%
len(df)
# Out:
# 125

# %%
df = df.dropna()

# %%
len(df)
# Out:
# 119

# %%
df.head()
# Out:
#   regular_periods rapid_weight_gain excess_hair dark_patches pimples  \
# 0              hb                 y           y            n       y
# 1              im                 y           y            n       n
# 2              hb                 y           y            n       n
# 3              ib                 n           y            n       n
# 4              im                 y           y            n       n
#
#   depression_and_anxiety diabetic_hypertension_family_history  \
# 0                      y                                    n
# 1                      y                                    n
# 2                      y                                    n
# 3                      y                                    y
# 4                      y                                    y
#
#   body_weight_maintain_difficulty oily_skin hair_strength_loss eat_frequency  \
# 0                               y         y                  y            hm
# ...

# %%
df.to_csv(path_or_buf='pcos_data.csv')

# %%
import json

# select 3  samples from the dataframe
x_df=df.sample(3)
y_df = x_df.pop('PCOS')

x_df['Column1'] = 0.0

# convert the records to a json data file
recored=x_df.to_dict(orient='records')

scoring_json = json.dumps({'data': recored})
print(scoring_json)
# Out:
# {"data": [{"regular_periods": "yes", "rapid_weight_gain": "n", "excess_hair": "n", "dark_patches": "n", "pimples": "n", "depression_and_anxiety": "n", "diabetic_hypertension_family_history": "n", "body_weight_maintain_difficulty": "n", "oily_skin": "n", "hair_strength_loss": "y", "eat_frequency": "hm", "regular_excercise": "n", "sleep_time": "3:00am", "wake_time": "7:30am", "hostel_stress": "n", "personal_stress": "n", "peer_pressure": "n", "dietary_stress": "y", "fast_food_frequency": "w", "Column1": 0.0}, {"regular_periods": "yes", "rapid_weight_gain": "n", "excess_hair": "n", "dark_patches": "n", "pimples": "n", "depression_and_anxiety": "n", "diabetic_hypertension_family_history": "n", "body_weight_maintain_difficulty": "n", "oily_skin": "n", "hair_strength_loss": "y", "eat_frequency": "hm", "regular_excercise": "y", "sleep_time": "11.30pm", "wake_time": "6.30am", "hostel_stress": "n", "personal_stress": "n", "peer_pressure": "n", "dietary_stress": "y", "fast_food_frequency": "m"
# ...
